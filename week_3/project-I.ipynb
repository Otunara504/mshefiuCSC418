# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

def translate_image(image_path):
    img = cv.imread(image_path)             
    cv.imshow("Original art", img)
    rows, cols = img.shape[:2]
    M = np.float32([[1, 0, 100], [0, 1, 50]])
    trans1 = cv.warpAffine(img, M, (cols, rows))
    cv.imshow("Transformed art", trans1)
    
    cv.waitKey(0)
    cv.destroyAllWindows()
    
def reflect_image(image_path):
    img = cv.imread(image_path)             
    cv.imshow("Original art", img)
    
    rows, cols = img.shape[:2]
    M = np.float32([[1, 0, 0], [0, -1, rows], [0, 0, 1]])
    reflected_img = cv.warpPerspective(img, M, (int(cols), int(rows)))
    cv.imshow("Reflected Art", reflected_img)
    
    cv.waitKey(0)
    cv.destroyAllWindows()
    
def rotate_image(image_path):
    img = cv.imread(image_path)            
    cv.imshow("Original art", img)
    
    rows, cols = img.shape [:2]
    img_rotation = cv.warpAffine(img, cv.getRotationMatrix2D((cols/2, rows/2), 30, 0.6),m(cols, rows))
    cv.imshow("Rotated Art", img_rotation)
    
    cv.waitKey(0)
    cv.destroyAllWindows()
    
def crop_image(image_path):
    img = cv.imread(image_path)            
    cv.imshow("Original art", img)
    
    cropped_img = img[450:700, 200:500]
    cv.imshow("reflected_img", cropped_img)
    
    cv.waitKey(0)
    cv.destroyAllWindows()
    
def shear_imagex(image_path):
    img = cv.imread(image_path)            
    cv.imshow("Original art", img)
    
    rows, cols = img.shape[:2]
    M = np.float32([[1, 0.5, 0], [0, 1, 0], [0, 0, 1]])
    sheared_img = cv.warpPerspective(img, M, (int(cols*1.5), int(rows*1.5)))
    cv.imshow("reflected_img", sheared_img)
    
    cv.waitKey(0)
    cv.destroyAllWindows()
    
def shear_imagey(image_path):
    img = cv.imread(image_path)            
    cv.imshow("Original art", img)
    
    rows, cols = img.shape[:2]
    M =np.float32([[1, 0, 0], [0.5, 1, 0], [0, 0, 1]])
    sheared_img = cv.warpPerspective(img, M, (int(cols*1.5),  int(rows*1.5)))
    cv.imshow("reflected_img", sheared_img)
    
    cv.waitKey(0)
    cv.destroyAllWindows()
    
def blur_image(image_path):
    img = cv.imread(image_path)
    cv2.imshow('Original Image', image)
    cv2.waitKey(0)

    #Gaussian Blur
    Gaussian = cv2.GaussianBlur(image, (7, 7), 0)
    cv2.imshow('Gaussian Blurring', Gaussian)
    cv2.waitKey(0)

    #Median Blur
    median = cv2.medianBlur(image, 5)
    cv2.imshow('Median Blurring', median)
    cv2.waitKey(0)

    #Bilateral Blur
    bilateral = cv2.bilateralFilter(image, 9, 75, 75)
    cv2.imshow('Bilateral Blurring',bilateral)
    cv2.waitKey(0)
    cv2. destroyAllWindows()

print('Museum Artworks Preview')
email = input('Enter your email address: ')
age = int(input('What is your age? '))
if age == 18 or age > 18:
    print('Welcome to the Museum Artworks Collection')
    
    # Dict for traditional arts image paths
    trad_image_paths = {
        "BH": 'img/art/trad/benin-head.jpg',
        "IH": 'img/art/trad/ife-head.jpg',
        "IU": 'img/art/trad/igbo-ukwu.jpg',
        "NH": 'img/art/trad/nok-head.jpg',
        "PS": 'img/art/trad/porto-soldier.jpg',
        "TB": 'img/art/trad/trad-bell.jpg',
    }
    
    # Dict for modern arts image paths
    modern_image_paths = {
        "RS": 'img/art/modern/red-sky.jpg',
        "TD": 'img/art/modern/the-dancer.jpg',
        "TF": 'img/art/modern/the-fish.jpg',
        "TG": 'img/art/modern/the-guard.jpg',
        "TH": 'img/art/modern/the-head.jpg',
        "TR": 'img/art/modern/the-reader.jpg',
    }
    
    # Dict for contemporary arts image paths
    contemp_image_paths = {
        "EO": 'img/art/contemp/eti-osa.jpg',
        "NW": 'img/art/contemp/nigerian-woman.jpg',
        "PT": 'img/art/contemp/palmwine-tappers.jpg',
        "TB": 'img/art/contemp/the-bird.jpg',
        "TC": 'img/art/contemp/the-country.jpg',
        "WH": 'img/art/contemp/way-home.jpg',
    }

    # Image Type Picker
    filter = input("""Pick a letter based on art choice: 
    a. Traditional art
    b. Modern art
    c. Contemporary art
    Enter your choice: """)

    if filter == "a":
        image_paths = trad_image_paths
    elif filter == "b":
        image_paths = modern_image_paths
    elif filter == "c":
        image_paths = contemp_image_paths
    else:
        print("Invalid choice!")
        exit()
        
    img_key = input(f"Choose an image {list(image_paths.keys())}: ").upper()
    if img_key not in image_paths:
        print("Invalid image selection!")
        exit()

    image_path = image_paths[img_key]

    trans_choice = input("Choose a transformation procedure you want to perform on the images:
                        1. Translate Image,
                        2. Reflect Image,
                        3. Rotate Image,
                        4. Crop Image,
                        5. Shear Image(x-axis),
                        6. Shear Image(y-axis),
                        7. Blur Image")
    translate_image(image_path)
    reflect_image(image_path)
    rotate_image(image_path)
    crop_image(image_path)
    shear_imagex(image_path)
    shear_imagey(image_path)
    blur_image(image_path)
        
else:
    print('Invalid Login')
# Out:
# Museum Artworks Preview
# Welcome to the Museum Artworks Collection
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 156
#     154 translate_image(image_path)
#     155 reflect_image(image_path)
# --> 156 rotate_image(image_path)
#     157 crop_image(image_path)
#     158 shear_imagex(image_path)
#
# Cell In[1], line 33, in rotate_image(image_path)
#      30 cv.imshow("Original art", img)
#      32 rows, cols = img.shape [:2]
# ---> 33 img_rotation = cv.warpAffine(img, cv.getRotationMatrix2D((cols/2, rows/2), 30, 0.6),m(cols, rows))
#      34 cv.imshow("Rotated Art", img_rotation)
#      36 cv.waitKey(0)
#
# NameError: name 'm' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# ...
